# %% [markdown]
# <a href="https://colab.research.google.com/github/mzaib1012/priority-rtos-core/blob/main/RTOS_Core_Simulation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Clone the repository
# !git clone https://github.com/mzaib1012/priority-rtos-core.git
# %cd priority-rtos-core
# Out:
# Cloning into 'priority-rtos-core'...
# remote: Enumerating objects: 27, done.
# remote: Counting objects: 100% (27/27), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 27 (delta 7), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (27/27), 11.97 KiB | 645.00 KiB/s, done.
# Resolving deltas: 100% (7/7), done.
# /content/priority-rtos-core

# %%
# Clean compile: The -Iinclude flag tells GCC where to find your header file
# !gcc src/rtos.c tests/main.c -Iinclude -o rtos_simulation

# %%
# Run the simulation
# !./rtos_simulation
# Out:
# Streaming output truncated to the last 5000 lines.
# [TASK] Task 0 [High_Monitor] gracefully yielded control.
#
# --- [SCHEDULER] Context Switch -> Running Task 0 [High_Monitor] ---
# [EXEC] Task High Running: Inspecting system health...
# [EXEC] Task High: Everything stable.
# [TASK] Task 0 [High_Monitor] gracefully yielded control.
#
# --- [SCHEDULER] Context Switch -> Running Task 0 [High_Monitor] ---
# [EXEC] Task High Running: Inspecting system health...
# [EXEC] Task High: Everything stable.
# [TASK] Task 0 [High_Monitor] gracefully yielded control.
#
# --- [SCHEDULER] Context Switch -> Running Task 0 [High_Monitor] ---
# [EXEC] Task High Running: Inspecting system health...
# [EXEC] Task High: Everything stable.
# [TASK] Task 0 [High_Monitor] gracefully yielded control.
#
# --- [SCHEDULER] Context Switch -> Running Task 0 [High_Monitor] ---
# [EXEC] Task High Running: Inspecting system health...
# [EXEC] Task High: Everything stable.
# ...
